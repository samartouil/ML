# %% [markdown]
# <a href="https://colab.research.google.com/github/samartouil/ML/blob/samar/Projet_ML_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Business Understanding

# %%
hhh

# %% [markdown]
# # Data Understanding

# %% [markdown]
# # Data Preparation

# %% [markdown]
# # Modeling

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Deployment
